# %% [markdown]
# **Linear Regression and Its Application in Data Science**
#
# Linear regression is a statistical method used to model the relationship between two or more variables. It assumes that there is a linear relationship between the independent variable(s) and the dependent variable. In simple linear regression, there is only one independent variable, while in multiple linear regression, there are multiple independent variables.
#
# **Concept of Linear Regression:**
#
# The concept of linear regression revolves around fitting a straight line to the data points to model the relationship between the independent variable(s) and the dependent variable. The equation of a simple linear regression model can be represented as:
#
# Y=β
# 0
# ​
#  +β
# 1
# ​
#  X+ϵ
#
# -  Y  is the dependent variable (the variable we want to predict).
# -  X  is the independent variable (the variable used to make predictions).
# - β
# 0 is the y-intercept (the value of  Y  when X  is zero).
# - β
# 1 is the slope of the line (the change in  Y for a unit change in X ).
# - ϵ represents the error term (the difference between the observed Y and the predicted  Y ).
#
# **Application in Data Science:**
#
# Linear regression is widely used in data science for various purposes, including:
#
# 1. **Prediction**: It can be used to predict the value of the dependent variable based on the values of the independent variables. For example, predicting house prices based on features like square footage, number of bedrooms, etc.
#
# 2. **Relationship Analysis**: It helps in analyzing the relationship between variables. For instance, determining the impact of advertising spending on sales revenue.
#
# 3. **Trend Analysis**: Linear regression can be used to identify trends and patterns in data over time. For example, analyzing the trend of temperature changes over the years.
#
# 4. **Model Evaluation**: It is used to evaluate the strength and significance of the relationship between variables, as well as to assess the performance of predictive models.
#
# In data science projects, linear regression serves as a fundamental tool for understanding and modeling the relationship between variables, making predictions, and deriving insights from data.

# %% [markdown]
# **Case Study: Predicting Housing Prices using Linear Regression**
#
# In this case study, we'll explore how linear regression can be used to predict housing prices based on various features such as square footage, number of bedrooms, and other relevant factors.
#
# **Data Description:**
#
# We have a dataset containing information about houses, including features such as:
# - Square footage (size of the house)
# - Number of bedrooms
# - Number of bathrooms
# - Location (e.g., zip code or neighborhood)
# - Year built
# - Sale price (target variable)
#
# **Objective:**
#
# Our goal is to build a linear regression model that can predict the sale price of a house based on its features.
#
# **Steps:**
#
# 1. **Data Exploration and Preprocessing:**
#    - Load the dataset and explore its structure.
#    - Check for missing values and handle them if necessary.
#    - Perform any necessary data transformations (e.g., encoding categorical variables).
#
# 2. **Feature Selection:**
#    - Identify relevant features that may affect the sale price of a house.
#    - Select features with strong correlations with the target variable (sale price).
#
# 3. **Model Building:**
#    - Split the dataset into training and testing sets.
#    - Train a linear regression model using the training data.
#    - Evaluate the model's performance on the testing data using metrics like mean squared error (MSE) or R-squared.
#
# 4. **Prediction:**
#    - Use the trained model to predict the sale prices of houses in the testing set.
#    - Compare the predicted prices with the actual prices to assess the model's accuracy.
#
# **Conclusion:**
#
# Linear regression can be a powerful tool for predicting housing prices based on features like square footage, number of bedrooms, and bathrooms. By analyzing historical data and building a predictive model, real estate professionals and homeowners can make informed decisions about pricing and investments.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.formula.api as smf

df = pd.read_csv("C:/Users/User/Downloads/data1.csv", header=0, sep=",")

x = df["Pulse"]
y = df["Calories"]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
 return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.ylim(ymin=0, ymax=2000)
plt.xlim(xmin=0, xmax=200)
plt.xlabel("Pulse")
plt.ylabel ("Calories")
plt.show()

# %%
model = smf.ols('Calories ~ Pulse', data = full_health_data)
results = model.fit()
print(results.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model = smf.ols('Calories ~ Pulse', data = full_health_data)
#       2 results = model.fit()
#       3 print(results.summary())
#
# NameError: name 'full_health_data' is not defined

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%20%2862%29-2.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%20%2862%29-2.png)
#
# 2. **REGRESSION INFO**
#
# **Dep. Variable:** is short for "Dependent Variable". Calories is here the dependent variable. The Dependent variable is here assumed to be explained by Pulse.
#
# **Model:** OLS is short for Ordinary Least Squares. This is a type of model that uses the Least Square method.
#
# **Date:** and **Time:** shows the date and time the output was calculated in Python.

# %% [markdown]
# 3. **COEFFICIENTS**
#
# ![coef.png](attachment:coef.png)
#
# The linear regression function can be rewritten mathematically as:
#
# Calorie = 0.3869 * Pulse + 337.8396
#
# - If Average_Pulse increases by 1, Calorie_Burnage increases by 0.3869 (or 0,4 rounded)
# - If Average_Pulse = 0, the Calorie_Burnage is equal to 337.8396 (or 337.9 rounded).
# - Remember that the intercept is used to adjust the model's precision of predicting!
#
# - Define the linear regression function in Python to perform predictions:
#    - What is Calories if Pulse is: 90, 100, 110, 150?

# %%
def Predict_Calories(Pulse):
 return(0.3296*Pulse + 346.8662)

print(Predict_Calories(90))
print(Predict_Calories(100))
print(Predict_Calories(110))
print(Predict_Calories(150))
# Out:
# 376.5302
# 379.8262
# 383.1222
# 396.3062

# %% [markdown]
# 4.**P-Value**

# %% [markdown]
# ![Std.png](attachment:Std.png)
# Now, we want to test if the coefficients from the linear regression function has a significant impact on the dependent variable (Calories).
#
# This means that we want to prove that it exists a relationship between Pulse and Calories, using statistical tests.
#
# There are four components that explains the statistics of the coefficients:
#
# - std err stands for Standard Error
# - t is the "t-value" of the coefficients
# - P>|t| is called the "P-value"
# -  [0.025  0.975] represents the confidence interval of the coefficients
#
# The P-value, or probability value, is a statistical measure used to determine the strength of evidence against the null hypothesis. In the context of hypothesis testing, it tells us the probability of observing the data or something more extreme if the null hypothesis is true.
#
# In hypothesis testing, we assess whether the true coefficient is zero, indicating no relationship.
#
# - A low P-value (< 0.05) suggests that the coefficient is likely not zero, indicating a relationship.
# - Conversely, a high P-value (> 0.05) suggests that we cannot conclude the explanatory variable affects the dependent variable (in this case, whether Pulse affects Calories).
# - mA high P-value is also referred to as an insignificant P-value.
#
# Hypothesis testing is a statistical procedure to test if  results are valid.
#
# In our example, we are testing if the true coefficient of Pulse and the intercept is equal to zero.
#
# Hypothesis test has two statements. The null hypothesis and the alternative hypothesis.
#
# - The null hypothesis can be shortly written as H0
# - The alternative hypothesis can be shortly written as HA
#
# Mathematically written:
#
# - H0: Average_Pulse = 0
# - HA: Average_Pulse ≠ 0
# - H0: Intercept = 0
# - HA: Intercept ≠ 0
#
# The null hypothesis can either be rejected or not.
#
# If we reject the null hypothesis, we conclude that it exist a relationship between Pulse and Calories. The P-value is used for this conclusion.
#
# A common threshold of the P-value is 0.05.
#
# If the P-value is lower than 0.05, we can reject the null hypothesis and conclude that it exist a relationship between the variables.
#
# However, the P-value of Average_Pulse is 0.791. So, we cannot conclude a relationship between Pulse and Calorie_Burnage.
#
# It means that there is a 79.1% chance that the true coefficient of Pulse is zero.
#
# The intercept is used to adjust the regression function's ability to predict more precisely. It is therefore uncommon to interpret the P-value of the intercept.

# %% [markdown]
# 5.**R-Squared and Adjusted R-Squared describes how well the linear regression model fits the data points:**
# ![R-sq.png](attachment:R-sq.png)
# The value of R-Squared is always between 0 to 1 (0% to 100%).
#
# A high R-Squared value means that many data points are close to the linear regression function line.
# A low R-Squared value means that the linear regression function line does not fit the data well.

# %% [markdown]
# Regression model above shows a R-Squared value of zero, which means that the linear regression function line does not fit the data well.
#
# This can be visualized when we plot the linear regression function through the data points of Pulse and Calories.
#
# However, if we plot Duration and Calories, the R-Squared increases. Here, we see that the data points are close to the linear regression function line:

# %%
x = df ["Duration"]
y = df ["Calories"]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
 return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.ylim(ymin=0, ymax=2000)
plt.xlim(xmin=0, xmax=200)
plt.xlabel("Duration")
plt.ylabel ("Calories")

plt.show()

# %% [markdown]
# Coefficient of 0.3869, which means that Pulse has a very small effect on Calories.
# High P-value (0.791), which means that we cannot conclude a relationship between Pulse and Calories.
# R-Squared value of 0, which means that the linear regression function line does not fit the data well.
